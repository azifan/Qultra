# %%
import pydicom as dicom
import numpy as np
import matplotlib.pyplot as plt
from pydicom.pixel_data_handlers import convert_color_space

# %%
path = "/Volumes/CREST Data/David_S_Data/MC_2d_DICOM_Sample/cleaned_UCSD/P_009_010/DICOM_cine/ceus_inj1_wi_000000.000000.dcm"
# path = "/Volumes/CREST Data/David_S_Data/MC_Sample_Code/data/P_005_021/DICOM_cine/ceus_inj1_wi_000000.000000.dcm"

# %%
ds = dicom.dcmread(path)
# ar = convert_color_space(ds.pixel_array, "YBR_FULL_422", "RGB", per_frame=True)
print(ds)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Ultrasound Multi-frame Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113654.2.70.1.5030210890465552655720697049789266842
# (0002, 0010) Transfer Syntax UID                 UI: JPEG 2000 Image Compression (Lossless Only)
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.38'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'ABDOMINAL', '0000', 'GEMSMULTIFRAME', 'GEMSMGCOUNT1']
# (0008, 0016) SOP Class UID                       UI: Ultrasound Multi-frame Image Storage
# ...

# %%
ar = ds.pixel_array
print(ar.shape)
plt.imshow(ar[0,:,:int(ar.shape[2]/2),:])
# Out:
# (641, 802, 1442, 3)

# %%
plt.imshow(ar[0,:,int(ar.shape[2]/2):,:])

# %%
plt.imshow(ar[0,:,int(ar.shape[2]/2):,0], cmap="Greys_r")

# %%
new_path = "/Volumes/CREST Data/David_S_Data/MC_2d_DICOM_Sample/cleaned_UCSD/P_009_010/DICOM_cine/ceus_inj1_wi_000000.000000.dcm"
new_ds = dicom.dcmread(new_path)
print(new_ds)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 212
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Ultrasound Multi-frame Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.392.200036.9116.6.22.10500000.1644.20180606204703604.1.57
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Baseline (Process 1)
# (0002, 0012) Implementation Class UID            UI: 1.2.392.200036.9116.6.22.1000.1
# (0002, 0013) Implementation Version Name         SH: 'TM_UL_DCM_V1.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'ABDOMINAL', '0001']
# (0008, 0012) Instance Creation Date              DA: '20180606'
# (0008, 0013) Instance Creation Time              TM: '134703.584'
# ...

# %%
new_ar = new_ds.pixel_array
print(new_ar.shape)
plt.imshow(ar[0,:,:int(ar.shape[2]/2),0], cmap="Greys_r")
# Out:
# (566, 960, 1280, 3)

# %%
plt.figure(dpi=400)
plt.imshow(new_ar[0,:,:,0], cmap="Greys_r")
